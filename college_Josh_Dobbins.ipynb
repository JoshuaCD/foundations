# %% [markdown]
# ## Introduction
#
# We'll explore how using the pandas plotting functionality along with the Jupyter notebook interface allows us to explore data quickly using visualizations.
#
# We'll be working with a dataset on the job outcomes of students who graduated from college between 2010 and 2012. The original data on job outcomes was released by [American Community Survey](https://www.census.gov/programs-surveys/acs/), which conducts surveys and aggregates the data. FiveThirtyEight cleaned the dataset and released it on their [Github repo](https://github.com/fivethirtyeight/data/tree/master/college-majors).

# %% [markdown]
# ## Assignment
#
# - Import pandas and matplotlib (remember "% matplotlib inline")
# - Read in the data and explore the head and tail
# - Drop any rows with missing values

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib as plt

college_majors = pd.read_csv("recent-grads.csv")

print("Shape \n",college_majors.shape,"\n")

print("Data Types \n",college_majors.dtypes,"\n")

print("Head \n",college_majors.head(5),"\n")

print("Tail",college_majors.tail(5),"\n")

college_majors = college_majors.dropna()

print("Null values removed shape \n",college_majors.shape)
# Out:
# Shape
#  (173, 21)
#
# Data Types
#  Rank                      int64
# Major_code                int64
# Major                    object
# Major_category           object
# Total                     int64
# Sample_size               int64
# Men                       int64
# Women                     int64
# ShareWomen              float64
# Employed                  int64
# Full_time                 int64
# Part_time                 int64
# Full_time_year_round      int64
# Unemployed                int64
# Unemployment_rate       float64
# Median                    int64
# P25th                     int64
# P75th                     int64
# College_jobs              int64
# Non_college_jobs          int64
# Low_wage_jobs             int64
# dtype: object
#
# Head
#     Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# ...

# %% [markdown]
# ## Assignment
#
# Feel free to use native panda graphing methods.
#
# - Make a scatter plot of sample size vs. median
# - Make a scatter plot of sample size vs. unemployment rate
# - Make a scatter plot of full time vs. median
# - Make a scatter plot of men vs. median
# - Make a scatter plot of women vs. median

# %%
college_majors.plot(kind='scatter', y='Sample_size', x='Median')

college_majors.plot(kind='scatter', y='Sample_size', x='Unemployment_rate')

college_majors.plot(kind='scatter', y='Full_time', x='Median')

college_majors.plot(kind='scatter', y='Men', x='Median')

college_majors.plot(kind='scatter', y='Women', x='Median')

# %% [markdown]
# ## Assignment
#
# - Create a for loop that plots the histogram of sample size, median, employed, full time, unemployment rate, men and women (remember to use the exact column titles)

# %%
histVars=['Sample_size', 'Median', 'Employed', 'Full_time', 'Unemployment_rate', 'Men', 'Women']

for i in range(0,6):

    college_majors.loc[:,histVars[i]].plot.hist(x=histVars[i])
    
    i+=1

# %% [markdown]
# ## Assignment
#
# - Make a scatter matrix of sample size and median
# - Make a scatter matrix of sample size, median and unemployment rate

# %%
 from pandas.plotting import scatter_matrix

scatter_matrix(college_majors.loc[:,['Median','Sample_size']])

scatter_matrix(college_majors.loc[:,['Median','Sample_size','Unemployment_rate']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EE091FE1D0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EE092B1978>]], dtype=object)

# %% [markdown]
# ## Assignment
#
# - Make a bar plot of majors vs "ShareWomen" (you should run different slices since there are many different majors)

# %%
college_majors.loc[1:20,:].plot.bar(x='Major',y='ShareWomen')
college_majors.loc[21:40,:].plot.bar(x='Major',y='ShareWomen')
college_majors.loc[41:60,:].plot.bar(x='Major',y='ShareWomen')
college_majors.loc[61:80,:].plot.bar(x='Major',y='ShareWomen')
college_majors.loc[81:100,:].plot.bar(x='Major',y='ShareWomen')
college_majors.loc[101:120,:].plot.bar(x='Major',y='ShareWomen')
college_majors.loc[121:140,:].plot.bar(x='Major',y='ShareWomen')
college_majors.loc[141:160,:].plot.bar(x='Major',y='ShareWomen')
college_majors.loc[161:172,:].plot.bar(x='Major',y='ShareWomen')
